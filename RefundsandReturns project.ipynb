# %%
import pandas as pd

# File paths
refunds_path = r"D:\Downloads\Transactions for time period 2025-06-01 - 2025-07-31.csv"
returns_path = r"D:\Downloads\89853020345.csv"
reimb_path   = r"D:\Downloads\89855020345.csv"

# Load Refunds
refunds = pd.read_csv(refunds_path, dtype=str, encoding="latin1")
refunds = refunds[["Order ID", "Product Details"]].copy()
refunds.rename(columns={"Order ID": "order_id", "Product Details": "product_name"}, inplace=True)

# Load Returns
returns = pd.read_csv(returns_path, dtype=str, encoding="latin1")
returns_ids = set(returns["order-id"].dropna().astype(str).str.strip())

# Load Reimbursements
reimb = pd.read_csv(reimb_path, dtype=str, encoding="latin1")
reimb_ids = set(reimb["amazon-order-id"].dropna().astype(str).str.strip())

# Status check (adds column to refunds)
refunds["status"] = refunds["order_id"].astype(str).str.strip().map(
    lambda oid: "Return or Reimbursement issued" if oid in returns_ids or oid in reimb_ids else "Needs Reimbursement"
)

# Final table
final = refunds[["order_id", "product_name", "status"]]

# Save directly to Downloads
final.to_excel(r"D:\Downloads\refunds_status_report1.xlsx", index=False)

final
# Out:
#                 order_id                                 product_name  \
# 0    702-3989664-3074612  New Era MLB The League 9FORTY Adjustable...
# 1    701-1765560-0636261  NIKE Plus Cushion Socks (6-Pair) (M (Men...
# 2    702-3634092-9516224  Nike Kids Brasilia Just Do It Backpack (...
# 3    702-3547238-9035420                  Nike JDI Zip Pull Lunch Bag
# 4    702-8697638-0695409  Nike No Show Performance Socks White Lar...
# ..                   ...                                          ...
# 104  702-0086218-3721007  New Era MLB The League 9FORTY Adjustable...
# 105  701-4629968-0484223  New Era Men's College Navy Seattle Seaha...
# 106  701-6452641-1198667  New Era New York Yankees Exclusive Selec...
# 107  702-6954633-2149842  New Era MLB The League 9FORTY Adjustable...
# 108  701-2237873-0289820  New Era MLB The League 9FORTY Adjustable...
#
#                              status
# 0               Needs Reimbursement
# 1               Needs Reimbursement
# 2    Return or Reimbursement issued
# 3               Needs Reimbursement
# 4               Needs Reimbursement
# ..                              ...
# 104             Needs Reimbursement
# 105             Needs Reimbursement
# 106             Needs Reimbursement
# 107             Needs Reimbursement
# 108             Needs Reimbursement
#
# [109 rows x 3 columns]
